# %%
import pandas as pd

data = pd.read_csv(r"C:\Users\shree\Downloads\Rishabh project\band_gap_train.csv")  ### here to select the input data file
print('Dataset shape:', data.shape)
print(data)
# Out:
# Dataset shape: (42090, 274)
#             mp-id  composition  mean_EffectiveCoordination  \
# 0         mp-3995    Si4Cu4La2                   10.923951
# 1      mp-1187966       Yb6Hf2                   11.999759
# 2      mp-1080317       Se8Ce4                    7.958294
# 3      mp-1025345    Ti4Cr2Te8                    9.108987
# 4      mp-1245500     N4Na4Pd4                   10.123507
# ...           ...          ...                         ...
# 42085  mp-1185226       La6Yb2                   11.991120
# 42086    mp-24102   H4O10V2Fe2                    7.665640
# 42087   mp-646420    Rh4In2Nd4                   10.929245
# 42088  mp-1021313    Mg12K2Hf2                   11.932149
# 42089  mp-1114155  Li2F12K4Ta2                   10.553945
#
#        var_EffectiveCoordination  min_EffectiveCoordination  \
# 0                   2.631224e+00                   8.390932
# 1                   2.220446e-15                  11.999759
# ...

# %%
data.head()
# Out:
#         mp-id composition  mean_EffectiveCoordination  \
# 0     mp-3995   Si4Cu4La2                   10.923951
# 1  mp-1187966      Yb6Hf2                   11.999759
# 2  mp-1080317      Se8Ce4                    7.958294
# 3  mp-1025345   Ti4Cr2Te8                    9.108987
# 4  mp-1245500    N4Na4Pd4                   10.123507
#
#    var_EffectiveCoordination  min_EffectiveCoordination  \
# 0               2.631224e+00                   8.390932
# 1               2.220446e-15                  11.999759
# 2               2.472266e+00                   4.178233
# 3               1.129941e+00                   7.325180
# 4               2.222709e+00                   6.789444
#
#    max_EffectiveCoordination  var_MeanBondLength  min_MeanBondLength  \
# 0                  17.502010        6.132989e-02            0.947517
# 1                  11.999759        2.775558e-17            1.000000
# 2                  10.544650        1.868658e-01            0.727072
# ...

# %%
from sklearn.utils import shuffle

features = list(data)[1:-1]
properties = list(data)[-1]
data = shuffle(data, random_state=0)
X = data[features]
y = data[properties]
print('number of features:', len(features))
# Out:
# number of features: 272

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42090 entries, 9907 to 2732
# Columns: 274 entries, mp-id to band_gap
# dtypes: float64(222), int64(50), object(2)
# memory usage: 88.3+ MB

# %%
from sklearn.model_selection import ShuffleSplit
n_samples = X.shape[0]
cv = ShuffleSplit(n_splits=5, test_size=0.3, random_state=0)
cross_val_score(clf, X, y, cv=5)
array([0.977..., 0.977..., 1.  ..., 0.955..., 1.        ])
# Out:
#   Input In [32]
#     array([0.977..., 0.977..., 1.  ..., 0.955..., 1.        ])
#            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
data.isnull()
# Out:
#        mp-id  composition  mean_EffectiveCoordination  \
# 9907   False        False                       False
# 39385  False        False                       False
# 39107  False        False                       False
# 37575  False        False                       False
# 20612  False        False                       False
# ...      ...          ...                         ...
# 41993  False        False                       False
# 32103  False        False                       False
# 30403  False        False                       False
# 21243  False        False                       False
# 2732   False        False                       False
#
#        var_EffectiveCoordination  min_EffectiveCoordination  \
# 9907                       False                      False
# 39385                      False                      False
# 39107                      False                      False
# 37575                      False                      False
# ...

# %%
data.isnull().sum()
# Out:
# mp-id                          0
# composition                    0
# mean_EffectiveCoordination    10
# var_EffectiveCoordination     10
# min_EffectiveCoordination     10
#                               ..
# frac_fValence                  0
# CanFormIonic                   0
# MaxIonicChar                   0
# MeanIonicChar                  0
# band_gap                       0
# Length: 274, dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 1260

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
import matplotlib

import matplotlib.pyplot as plt
plt.hist(data["band_gap"])
plt.xlabel("Number of crystal structures")
plt.ylabel("Frequency")
plt.show()

# %%
X = data.iloc[:,:-1]
y = data.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=100)

# %%
X_train.shape
# Out:
# (31560, 273)

# %%
y_train.shape
# Out:
# (31560,)

# %%
data_ = data.replace('[^\d]', '', regex= True)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor()

# %%
rf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 rf.fit(X_train, y_train)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_forest.py:331, in BaseForest.fit(self, X, y, sample_weight)
#     329 if issparse(y):
#     330     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 331 X, y = self._validate_data(
#     332     X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     333 )
#     334 if sample_weight is not None:
#     335     sample_weight = _check_sample_weight(sample_weight, X)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:596, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     594         y = check_array(y, input_name="y", **check_y_params)
#     595     else:
# ...

# %%
data.dtypes
# Out:
# mp-id                          object
# composition                    object
# mean_EffectiveCoordination    float64
# var_EffectiveCoordination     float64
# min_EffectiveCoordination     float64
#                                ...
# frac_fValence                 float64
# CanFormIonic                    int64
# MaxIonicChar                  float64
# MeanIonicChar                 float64
# band_gap                      float64
# Length: 274, dtype: object

# %%
data['CanFormIonic'] = data.CanFormIonic.astype(float)

# %%
data.dtypes
# Out:
# mp-id                          object
# composition                    object
# mean_EffectiveCoordination    float64
# var_EffectiveCoordination     float64
# min_EffectiveCoordination     float64
#                                ...
# frac_fValence                 float64
# CanFormIonic                  float64
# MaxIonicChar                  float64
# MeanIonicChar                 float64
# band_gap                      float64
# Length: 274, dtype: object

# %%
type(X_train)
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder(handle_unknown='ignore')
enc_X = enc.fit(X_train)
enc_Y = enc.fit(array.reshape.y_train(-1, 1))
rf.fit([enc_X], [y_train])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [60], in <cell line: 5>()
#       3 enc = OneHotEncoder(handle_unknown='ignore')
#       4 enc_X = enc.fit(X_train)
# ----> 5 enc_Y = enc.fit(array.reshape.y_train(-1, 1))
#       6 rf.fit([enc_X], [y_train])
#
# NameError: name 'array' is not defined

# %%
rf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [53], in <cell line: 1>()
# ----> 1 rf.fit(X_train, y_train)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_forest.py:331, in BaseForest.fit(self, X, y, sample_weight)
#     329 if issparse(y):
#     330     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 331 X, y = self._validate_data(
#     332     X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     333 )
#     334 if sample_weight is not None:
#     335     sample_weight = _check_sample_weight(sample_weight, X)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:596, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     594         y = check_array(y, input_name="y", **check_y_params)
#     595     else:
# ...
